# %%
from pymongo import MongoClient
import pandas as pd
import requests
import json
import matplotlib.pyplot as plt
import folium

# %% [markdown]
# ## 1. ANALYSIS OF LOCATION FOR GAMING RELATED COMPANIES

# %% [markdown]
# This information gives us a glimpse of where are the good markets due to the location of gaming companies headquarters.

# %%
gaming_df = pd.read_csv('../data/video_games_companies_cleaned.csv')

# %%
gaming_df
# Out:
#                  name category_code  number_of_employees total_money_raised  \
# 0             Flektor   games_video                  NaN                 $0
# 1                Lala   games_video                  NaN             $44.2M
# 2               Joost   games_video                  0.0               $45M
# 3            Babelgum   games_video                  NaN             $13.2M
# 4             Sparter   games_video                  NaN                 $0
# ..                ...           ...                  ...                ...
# 834  G5 Entertainment   games_video                107.0                 $0
# 835         Rev Media   games_video                  NaN                 $0
# 836        Fictionaut   games_video                  2.0                 $0
# 837        Tiny Speck   games_video                 45.0             $17.2M
# 838       My TV Shows   games_video                  2.0                 $0
#
#     country_code         city                      address    zip_code  \
# 0            USA  Culver City  8536 National Blvd, Suite A       90232
# 1            USA    Palo Alto             209 Hamilton Ave       94301
# 2            USA     New York             100 5th Ave Fl 6  10011-6903
# 3            GBR       London                          NaN         NaN
# 4            USA          NaN                          NaN         NaN
# ..           ...          ...                          ...         ...
# 834          UKR      Kharkov   Moskovskiy prospekt, 179-B       61037
# 835          USA       Dallas                          NaN         NaN
# 836          USA      Astoria                32-14 42nd St       11103
# 837          CAN    Vancouver            163 Hastings St W  BC V6B 1H5
# 838          PRT       Lisbon       Rua RosÃ¡lia de Castro        1700
#
#       latitude   longitude
# 0    34.025958 -118.379768
# 1    37.451151 -122.154369
# 2    40.746497  -74.009447
# 3    53.344104   -6.267494
# 4    37.090240  -95.712891
# ..         ...         ...
# 834        NaN         NaN
# 835        NaN         NaN
# 836  40.759795  -73.916127
# 837  49.282455 -123.109217
# 838  38.752367   -9.146221
#
# [839 rows x 10 columns]

# %%
gaming_country_counts = gaming_df['country_code'].value_counts().head(10)

# Convert the Series to a DataFrame
top_10_countries_gaming_df = gaming_country_counts.reset_index()
top_10_countries_gaming_df.columns = ['Country', 'Number of Companies']

# Now 'top_countries_df' is the DataFrame with the top 10 countries
top_10_countries_gaming_df
# Out:
#   Country  Number of Companies
# 0     USA                  534
# 1     GBR                   62
# 2     CAN                   35
# 3     FRA                   23
# 4     DEU                   22
# 5     ISR                   19
# 6     CHN                   14
# 7     JPN                   13
# 8     ESP                   12
# 9     IND                   12

# %%
# Count the number of occurrences of each country in the DataFrame
top_5_gaming_countries_plot = gaming_df['country_code'].value_counts().head(5)

# Generate the bar plot
plt.figure(figsize=(8, 6))
top_5_gaming_countries_plot.plot(kind='bar', color='skyblue')
plt.title('Top 5 Countries with Most Gaming Companies')
plt.xlabel('Country Code')
plt.ylabel('Number of Companies')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# First, let's filter for companies in the US
top_us_gaming_cities = gaming_df[gaming_df['country_code'] == 'USA']

# Now, we calculate the value counts for the 'city' column for US companies
top_5_us_gaming_cities_plot = top_us_gaming_cities['city'].value_counts().head(5)

# Now we'll create the bar plot using matplotlib
plt.figure(figsize=(8, 6))
top_5_us_gaming_cities_plot.plot(kind='bar', color='skyblue')
plt.title('Top 5 US Cities with Most Gaming Companies')
plt.xlabel('City')
plt.ylabel('Number of Companies')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## 2. ANALYSIS OF EMPLOYEES REQUIREMENTS AND LOCATIONS

# %% [markdown]
# This first analysis for employees requirements will attemp to fullfill the expectations for the major percentage of employees.

# %%
# Define the requirements as a list of dictionaries
requirements = [
    {"Employee Group": "Designers", "Requirement": "Design Community", "% of Employees": 23},
    {"Employee Group": "UI/UX Engineers", "Requirement": "Design Community", "% of Employees": 6},
    {"Employee Group": "Frontend Developers", "Requirement": "Tech Environment", "% of Employees": 11.5},
    {"Employee Group": "Data Engineers", "Requirement": "Tech Environment", "% of Employees": 17},
    {"Employee Group": "Backend Developers", "Requirement": "Tech Environment", "% of Employees": 6},
    {"Employee Group": "Account Managers", "Requirement": "Accessibility", "% of Employees": 23},
     {"Employee Group": "Maintenance Personnel", "Requirement": "Recreational Facilities", "% of Employees": 1},
    {"Employee Group": "Executives", "Requirement": "Starbucks", "% of Employees": 11.5},
    {"Employee Group": "CEO/President", "Requirement": "Vegan Restaurant", "% of Employees": 1}]
    

# Create a DataFrame from the list of dictionaries
requirements_df = pd.DataFrame(requirements)
requirements_df
# Out:
#           Employee Group              Requirement  % of Employees
# 0              Designers         Design Community            23.0
# 1        UI/UX Engineers         Design Community             6.0
# 2    Frontend Developers         Tech Environment            11.5
# 3         Data Engineers         Tech Environment            17.0
# 4     Backend Developers         Tech Environment             6.0
# 5       Account Managers            Accessibility            23.0
# 6  Maintenance Personnel  Recreational Facilities             1.0
# 7             Executives                Starbucks            11.5
# 8          CEO/President         Vegan Restaurant             1.0

# %% [markdown]
# By looking what countries/cities have more design companies or companies that have raised more than $1M, I saw there are only 4 design companies in the dataset but I can still fullfill the requirements of 33.5% of employees.

# %%
required_companies_df = pd.read_csv('../data/required_companies.csv')

# %%
required_companies_df
# Out:
#                          name  category_code total_money_raised country_code  \
# 0                        Digg           news               $45M          USA
# 1                       Joost    games_video               $45M          USA
# 2                     SpinVox      messaging              $106M          GBR
# 3                     AddThis    advertising               $73M          USA
# 4                      Mahalo            web               $21M          USA
# ...                       ...            ...                ...          ...
# 1651          Luminus Devices          other              $136M          USA
# 1652           Cameron Health        medical              $121M          USA
# 1653                 Cantimer            NaN                $2M          USA
# 1654  Celestial Semiconductor  semiconductor                $2M          USA
# 1655          InSound Medical        biotech               $11M          USA
#
#                  city                           address    zip_code  \
# 0       San Francisco                135 Mississippi St       94107
# 1            New York                  100 5th Ave Fl 6  10011-6903
# 2     Buckinghamshire        Wethered House, Pound Lane     SL7 2AF
# 3              Vienna             1595 Spring Hill Road       22182
# 4         Culver City                  3525 Eastham Dr.       90232
# ...               ...                               ...         ...
# 1651        Billerica        1100 Technology Park Drive       01821
# 1652     San Clemente                905 Calle Amanecer       92673
# 1653       Menlo Park                  3700 Haven Court       94025
# 1654         San Jose  2635 North 1st Street, Suite 150       95134
# 1655           Newark                39660 Eureka Drive       94560
#
#        latitude   longitude
# 0     37.764726 -122.394523
# 1     40.746497  -74.009447
# 2           NaN         NaN
# 3     38.926172  -77.245195
# 4     34.017606 -118.487267
# ...         ...         ...
# 1651  42.528635  -71.278022
# 1652  33.448010 -117.607717
# 1653  37.484616 -122.181753
# 1654  37.386417 -121.929170
# 1655  37.512038 -121.998513
#
# [1656 rows x 9 columns]

# %%
required_country_counts = required_companies_df['country_code'].value_counts().head(10)

# Convert the Series to a DataFrame
top_10_required_countries_df = required_country_counts.reset_index()
top_10_required_countries_df.columns = ['Country', 'Number of Companies']

# Now 'top_countries_df' is the DataFrame with the top 10 countries
top_10_required_countries_df
# Out:
#   Country  Number of Companies
# 0     USA                 1274
# 1     ISR                   48
# 2     CAN                   44
# 3     GBR                   41
# 4     CHN                   37
# 5     IND                   26
# 6     DEU                   12
# 7     FRA                   11
# 8     SGP                    7
# 9     SWE                    6

# %%
# Count the number of occurrences of each country in the DataFrame
top_5_required_countries_plot = required_companies_df['country_code'].value_counts().head(5)

# Now we'll create the bar plot using matplotlib
plt.figure(figsize=(8, 6))
top_5_required_countries_plot.plot(kind='bar', color='skyblue')
plt.title('Top 5 Countries with Most Video Game Companies')
plt.xlabel('Country')
plt.ylabel('Number of Video Game Companies')
plt.xticks(rotation=0)
plt.tight_layout()  
plt.show()

# %%
# First, let's filter for companies in the US
top_us_required_cities = required_companies_df[required_companies_df['country_code'] == 'USA']

# Now, we calculate the value counts for the 'city' column for US companies
top_5_us_required_cities_plot = top_us_required_cities['city'].value_counts().head(5)

# Now we'll create the bar plot using matplotlib
plt.figure(figsize=(8, 6))
top_5_us_required_cities_plot.plot(kind='bar', color='skyblue')
plt.title('Top 5 US Cities with Most Companies')
plt.xlabel('City')
plt.ylabel('Number of Companies')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #### The country selected is USA because in both Analysis USA is the country with much more companies than other countries. The cities wit more companies and that are shared in both analysis are: San Francisco, New York and Palo Alto.

# %% [markdown]
# ## 3. COMPANIES IN THE US:

# %%
usa_companies_df = pd.read_csv('../data/usa_companies_cleaned.csv')

# %%
usa_companies_df
# Out:
#                                 name category_code  number_of_employees  \
# 0                           Wetpaint           web                 47.0
# 1                          AdventNet    enterprise                600.0
# 2                               Zoho      software               1600.0
# 3                               Digg          news                 60.0
# 4                           Facebook        social               5299.0
# ...                              ...           ...                  ...
# 9050  Contemporary Computer Services      software                  NaN
# 9051                            QSGI      software                164.0
# 9052                      AfterLogic      software                  NaN
# 9053             EnteGreat Solutions      software                  NaN
# 9054                       EnteGreat    enterprise                  NaN
#
#      total_money_raised country_code           city  \
# 0                $39.8M          USA        Seattle
# 1                    $0          USA     Pleasanton
# 2                    $0          USA     Pleasanton
# 3                  $45M          USA  San Francisco
# 4                $2.43B          USA     Menlo Park
# ...                 ...          ...            ...
# 9050                 $0          USA        Bohemia
# 9051                 $0          USA     Palm Beach
# 9052                 $0          USA     Livingston
# 9053                 $0          USA     Birmingham
# 9054                 $0          USA     Birmingham
#
#                             address    zip_code   latitude   longitude
# 0                  710 - 2nd Avenue       98104  47.603122 -122.333253
# 1                  4900 Hopyard Rd.       94588  37.692934 -121.904945
# 2                   4900 Hopyard Rd       94588  37.692934 -121.904945
# 3                135 Mississippi St       94107  37.764726 -122.394523
# 4                  1601 Willow Road       94025  37.416050 -122.151801
# ...                             ...         ...        ...         ...
# 9050       200 Knickerbocker Avenue       11716  40.775055  -73.088140
# 9051             400 Royal Palm Way       33480  26.705331  -80.041395
# 9052                  P.O. Box 2096       07039  40.793024  -74.323554
# 9053                            NaN         NaN  33.518885  -86.816068
# 9054  1900 International Park Drive  35243-4204  33.407786  -86.761302
#
# [9055 rows x 10 columns]

# %%
# Define the cities of interest
cities_of_interest = ['San Francisco', 'New York', 'Palo Alto']

# Filter the dataframe for companies in the specified cities
filtered_companies_df = usa_companies_df[usa_companies_df['city'].isin(cities_of_interest)]

# Show the filtered data
filtered_companies_df.reset_index(drop=True, inplace=True)
filtered_companies_df
# Out:
#                    name category_code  number_of_employees total_money_raised  \
# 0                  Digg          news                 60.0               $45M
# 1               Twitter        social               1300.0             $1.16B
# 2           StumbleUpon           web                  NaN             $18.5M
# 3                Scribd          news                 50.0             $25.8M
# 4                  Lala   games_video                  NaN             $44.2M
# ...                 ...           ...                  ...                ...
# 1590  Email Data Source           NaN                  NaN              $552k
# 1591             Vertro      software                 50.0              $250k
# 1592               ALOT      software                 50.0                 $0
# 1593             Nellix           NaN                  NaN              $6.5M
# 1594            DocASAP           web                  7.0              $800k
#
#      country_code           city                 address zip_code   latitude  \
# 0             USA  San Francisco      135 Mississippi St    94107  37.764726
# 1             USA  San Francisco         1355 Market St.    94103  37.776805
# 2             USA  San Francisco                     NaN      NaN  37.775196
# 3             USA  San Francisco       539 Bryant Street    94107  37.789634
# 4             USA      Palo Alto        209 Hamilton Ave    94301  37.451151
# ...           ...            ...                     ...      ...        ...
# 1590          USA       New York  65 Broadway, Suite 601    10006  40.707158
# 1591          USA       New York       143 Varick Street    10013  40.726160
# 1592          USA       New York       143 Varick Street    10013  40.726160
# 1593          USA      Palo Alto      2465-B Faber Place    94303  37.449972
# 1594          USA       New York             115 5th Ave    10003        NaN
#
#        longitude
# 0    -122.394523
# 1    -122.416924
# 2    -122.419204
# 3    -122.404052
# 4    -122.154369
# ...          ...
# 1590  -74.012163
# 1591  -74.006023
# 1592  -74.006023
# 1593 -122.116178
# 1594         NaN
#
# [1595 rows x 10 columns]

# %%
# Further filter the dataframe for companies with number of employees between 90 and 120
filtered_companies_by_employees_df = filtered_companies_df[
    filtered_companies_df['number_of_employees'].between(90, 120, inclusive='both')]

filtered_companies_by_employees_df
# Out:
#                                  name    category_code  number_of_employees  \
# 15                         Livestream      games_video                120.0
# 50                       PowerReviews           social                120.0
# 51                                hi5      games_video                100.0
# 109                        Greystripe      advertising                 90.0
# 172                          EchoSign              web                100.0
# 201                           Ingenio      advertising                120.0
# 204                         TrustedID         security                120.0
# 254                             Zynga      games_video                115.0
# 255                            Smaato      advertising                 95.0
# 282                           Mixbook              web                 90.0
# 299                        TheLadders              web                110.0
# 325                             ooVoo              web                 95.0
# 352                         99designs           design                100.0
# 355                          LiveRail      advertising                110.0
# 369                         Clickpass              web                 90.0
# 425                        WebCollage         software                100.0
# 458         Pure Digital Technologies         hardware                 95.0
# 475                            Mojiva           mobile                105.0
# 477                         ServePath         hardware                100.0
# 483                            GitHub         software                106.0
# 515                           Tealeaf      advertising                100.0
# 560                             [x+1]       enterprise                105.0
# 588                              iWin      games_video                103.0
# 598                         Cloudmark         security                100.0
# 616                  Epic Advertising              NaN                105.0
# 631                  Vernalis Systems         software                120.0
# 692                           Avature         software                120.0
# 710                            GoGrid  network_hosting                102.0
# 723                 Fulcrum Analytics         software                 99.0
# 751                            Minted        ecommerce                115.0
# 758                         Verticity         software                110.0
# 784                         Passlogix       enterprise                100.0
# 804                    Stack Exchange         software                100.0
# 866              Vichara Technologies         software                100.0
# 868                           XBOSoft         software                100.0
# 882                    Stack Exchange         software                100.0
# 944              Vichara Technologies         software                100.0
# 946                           XBOSoft         software                100.0
# 1064                           Twilio       enterprise                100.0
# 1133                        Solbright         software                100.0
# 1140              BCG Attorney Search            legal                100.0
# 1177                        SundaySky         software                103.0
# 1199                            [x+1]       enterprise                105.0
# 1218                            Skout           social                100.0
# 1325  Hirshorn Zuckerman Design Group      advertising                100.0
# 1428                           Corvil            other                100.0
# 1441                 Canopy Financial          finance                100.0
# 1445                  ContinuumGlobal            other                100.0
# 1470                           Quirky        ecommerce                120.0
# 1535                      ZoomSystems         hardware                100.0
# 1537                            Exent      games_video                100.0
# 1549                  Varonis Systems         software                120.0
# 1558                         Mashable             news                100.0
# 1570                         Fuze Box         software                120.0
#
#      total_money_raised country_code           city  \
# 15               $14.7M          USA       New York
# 50               $40.1M          USA  San Francisco
# 51                 $52M          USA  San Francisco
# 109              $17.6M          USA  San Francisco
# 172               $8.5M          USA      Palo Alto
# 201                  $0          USA  San Francisco
# 204                $25M          USA      Palo Alto
# 254               $860M          USA  San Francisco
# 255                $18M          USA  San Francisco
# 282                $11M          USA      Palo Alto
# 299              $7.25M          USA       New York
# 325                  $0          USA       New York
# 352                $35M          USA  San Francisco
# 355                $12M          USA  San Francisco
# 369                $20k          USA  San Francisco
# 425              $19.6M          USA       New York
# 458              $68.2M          USA  San Francisco
# 475              $45.8M          USA       New York
# 477                  $0          USA  San Francisco
# 483               $100M          USA  San Francisco
# 515                $12M          USA  San Francisco
# 560                $45M          USA       New York
# 588                  $0          USA  San Francisco
# 598              $38.5M          USA  San Francisco
# 616                $48M          USA       New York
# 631                  $0          USA       New York
# 692                  $0          USA       New York
# 710                  $0          USA  San Francisco
# 723                  $0          USA       New York
# 751              $52.7M          USA  San Francisco
# 758                  $0          USA       New York
# 784              $11.5M          USA       New York
# 804                $18M          USA       New York
# 866                  $0          USA       New York
# 868                  $0          USA  San Francisco
# 882                $18M          USA       New York
# 944                  $0          USA       New York
# 946                  $0          USA  San Francisco
# 1064              $104M          USA  San Francisco
# 1133                 $0          USA       New York
# 1140                 $0          USA       New York
# 1177               $37M          USA       New York
# 1199               $45M          USA       New York
# 1218               $22M          USA  San Francisco
# 1325                 $0          USA       New York
# 1428             $31.5M          USA       New York
# 1441             $89.5M          USA  San Francisco
# 1445                 $0          USA  San Francisco
# 1470              $175M          USA       New York
# 1535               $87M          USA  San Francisco
# 1537                $3M          USA       New York
# 1549             $28.8M          USA       New York
# 1558             $13.3M          USA       New York
# 1570                 $0          USA  San Francisco
#
#                                                address    zip_code   latitude  \
# 15                               111 8th Avenue, #1509       10011  40.726155
# 50                                       22 4th Street       94103  37.779558
# 51                                    55 Second Street       94105  37.788668
# 109                             160 Spear Street Fl 14       94105  37.710677
# 172                            555 Bryant Street, #101       94301  37.445326
# 201                                           PMB #331       94105        NaN
# 204                                 395 Page Mill Road       94306  37.520592
# 254                                    365 Vermont St.       94103  37.765158
# 255                        240 Stockton St, 10th Floor       94108        NaN
# 282                                    409 Sherman Ave  94306-1827  37.383844
# 299                                  137 Varick Street       10013  40.725883
# 325                           44 East 30th: 12th Floor       11201        NaN
# 352                                    447 Battery St.       94111  37.795531
# 355                                     575 Market St.       94105  37.787183
# 369                                                NaN         NaN  37.775196
# 425                      462 Seventh Avenue, 9th Floor       10018        NaN
# 458                          30 Maiden Lane, 6th Floor       94108        NaN
# 475                                      136 Baxter St       10013  40.718561
# 477                                   345 Spear Street       94105  37.789803
# 483                                    275 Brannan St.       94107  37.775196
# 515                                     45 Fremont St.       94105  37.791242
# 560                              315 Park Avenue South       10010  40.745507
# 588                                  45 Fremont Street       94105  37.781689
# 598                                    128 King Street       94107  37.779507
# 616                                 512 Seventh Avenue       10018  40.753403
# 631                                  353 Lexington Ave       10016        NaN
# 692                                     48 Wall Street       10005  40.706271
# 710                                  2 Harrison Street       94105  37.789525
# 723                                70 West 40th Street       10018        NaN
# 751                                   747 Front Street       94111  37.797435
# 758   Empire State Building 350 5th Avenue Suite# 5713       10118        NaN
# 784                                    75 Broad Street       10004        NaN
# 804                                  55 Broadway 26 FL       10006        NaN
# 866                                    111 John Street       10038  40.707549
# 868                                     640 Rocca Ave.       94080        NaN
# 882                                  55 Broadway 26 FL       10006        NaN
# 944                                    111 John Street       10038  40.707549
# 946                                     640 Rocca Ave.       94080        NaN
# 1064                           645 Harrison, 3rd Floor       94107  37.789850
# 1133                        641 Avenue of the Americas       10011        NaN
# 1140                                      445 Park Ave       10022  34.142839
# 1177                                    242 W. 27th ST       10001        NaN
# 1199                             315 Park Avenue South       10010  40.745507
# 1218                                        301 Howard       94105  37.780054
# 1325                                               NaN         NaN  40.756054
# 1428                                    777 Third Ave.       10017  40.754719
# 1441                                     201 Spear St.       94105  37.791388
# 1445                                 431 Bryant Street       94107  37.782467
# 1470                              606 West 28th Street       10012        NaN
# 1535                           22 4th Street, Floor 16       94103  37.781689
# 1537                                   632 W. 28th St.       10001  40.752380
# 1549           499 7th Avenue, 23rd Floor, South Tower       10018        NaN
# 1558                                304 Park Ave South  10010-3646  40.740154
# 1570                                         150 Spear       94105        NaN
#
#        longitude
# 15    -73.995625
# 50   -122.393041
# 51   -122.400558
# 109  -122.393230
# 172  -122.160671
# 201          NaN
# 204  -122.255907
# 254  -122.404234
# 255          NaN
# 282  -121.918319
# 299   -74.006196
# 325          NaN
# 352  -122.400598
# 355  -122.397759
# 369  -122.419204
# 425          NaN
# 458          NaN
# 475   -73.998662
# 477  -122.389757
# 483  -122.419204
# 515  -122.397133
# 560   -73.982624
# 588  -122.391061
# 598  -122.390710
# 616   -73.989189
# 631          NaN
# 692   -74.009242
# 710  -122.388657
# 723          NaN
# 751  -122.403175
# 758          NaN
# 784          NaN
# 804          NaN
# 866   -74.005600
# 868          NaN
# 882          NaN
# 944   -74.005600
# 946          NaN
# 1064 -122.400683
# 1133         NaN
# 1140 -118.132378
# 1177         NaN
# 1199  -73.982624
# 1218 -122.391249
# 1325  -73.986951
# 1428  -73.971107
# 1441 -122.392148
# 1445 -122.394255
# 1470         NaN
# 1535 -122.391061
# 1537  -74.005568
# 1549         NaN
# 1558  -73.986742
# 1570         NaN

# %%
filtered_companies_by_employees_df['category_code'].unique()
# Out:
# array(['games_video', 'social', 'advertising', 'web', 'security',
#        'design', 'software', 'hardware', 'mobile', 'enterprise', nan,
#        'network_hosting', 'ecommerce', 'legal', 'other', 'finance',
#        'news'], dtype=object)

# %% [markdown]
# ## *I will prioritize the offices in the games_video category that may already have the desire distribution.

# %%
# Filter the already filtered data by the category code 'games_video'
pre_selected_companies_df = filtered_companies_by_employees_df[
    filtered_companies_by_employees_df['category_code'] == 'games_video']

pre_selected_companies_df
# Out:
#             name category_code  number_of_employees total_money_raised  \
# 15    Livestream   games_video                120.0             $14.7M
# 51           hi5   games_video                100.0               $52M
# 254        Zynga   games_video                115.0              $860M
# 588         iWin   games_video                103.0                 $0
# 1537       Exent   games_video                100.0                $3M
#
#      country_code           city                address zip_code   latitude  \
# 15            USA       New York  111 8th Avenue, #1509    10011  40.726155
# 51            USA  San Francisco       55 Second Street    94105  37.788668
# 254           USA  San Francisco        365 Vermont St.    94103  37.765158
# 588           USA  San Francisco      45 Fremont Street    94105  37.781689
# 1537          USA       New York        632 W. 28th St.    10001  40.752380
#
#        longitude
# 15    -73.995625
# 51   -122.400558
# 254  -122.404234
# 588  -122.391061
# 1537  -74.005568

# %%
pre_selected_companies_df.to_csv('../data/pre_selected_companies.csv', index=False)

# %% [markdown]
# ## * I will decide the city based in where are more companies value in more than $1M

# %%
million_dollar_comapanies_df = pd.read_csv('../data/all_companies_cleaned_df.csv')

# %%
# Count the number of companies in each city
city_counts = million_dollar_comapanies_df['city'].value_counts()

# Find the city with the most companies
top_city = city_counts.idxmax()
top_city_count = city_counts.max()

top_city, top_city_count
# Out:
# ('San Francisco', 134)

# %%
# Since there are only two cities, we can plot them directly
# Plot a bar chart for the two cities
plt.figure(figsize=(8, 5))
city_counts.plot(kind='bar', color=['skyblue', 'lightgreen'])
plt.title('Number of Companies in Each City')
plt.xlabel('City')
plt.ylabel('Number of Companies')
plt.xticks(rotation=0)
plt.tight_layout()  # Adjust layout to prevent clipping of ylabel
plt.show()

# %% [markdown]
# ## FINALISTS: COMPANIES IN SAN FRANCISCO

# %%
# Filter the dataframe for companies located in San Francisco
sf_companies = million_dollar_comapanies_df[million_dollar_comapanies_df['city'] == 'San Francisco']

sf_companies.to_csv('../data/san_francisco_companies.csv', index=False)

sf_companies
# Out:
#                      name category_code  number_of_employees  \
# 1                     hi5   games_video                100.0
# 2                   Zynga   games_video                115.0
# 3                    iWin   games_video                103.0
# 5                    Digg          news                  NaN
# 7                 Prosper       finance                  NaN
# ..                    ...           ...                  ...
# 215      Recurrent Energy     cleantech                  NaN
# 217  Siluria Technologies      nanotech                  NaN
# 218           ZoomSystems      hardware                  NaN
# 224            TeachScape      software                  NaN
# 225               Roc2Loc     cleantech                  NaN
#
#     total_money_raised country_code           city                    address  \
# 1                 $52M          USA  San Francisco           55 Second Street
# 2                $860M          USA  San Francisco            365 Vermont St.
# 3                   $0          USA  San Francisco          45 Fremont Street
# 5                 $45M          USA  San Francisco         135 Mississippi St
# 7                $120M          USA  San Francisco             101 2nd Street
# ..                 ...          ...            ...                        ...
# 215               $85M          USA  San Francisco         300 California St.
# 217              $103M          USA  San Francisco        409 Illinois Street
# 218               $87M          USA  San Francisco    22 4th Street, Floor 16
# 224               $16M          USA  San Francisco           71 Stevenson St.
# 225                $2M          USA  San Francisco  66 Mint Street, 3rd Floor
#
#     zip_code   latitude   longitude  Company_Type
# 1      94105  37.788668 -122.400558  Pre-selected
# 2      94103  37.765158 -122.404234  Pre-selected
# 3      94105  37.781689 -122.391061  Pre-selected
# 5      94107  37.764726 -122.394523  Raised > $1M
# 7      94105  37.789760 -122.402524  Raised > $1M
# ..       ...        ...         ...           ...
# 215    94104  37.805289 -122.404448  Raised > $1M
# 217    94158  37.448491 -122.180281  Raised > $1M
# 218    94103  37.781689 -122.391061  Raised > $1M
# 224    94105  37.786905 -122.404392  Raised > $1M
# 225    94103  37.782475 -122.407764  Raised > $1M
#
# [134 rows x 11 columns]

# %%
# Filter the San Francisco dataframe further to include only companies with Company_Type 'Pre-selected'
companies_sf_preselected = sf_companies[sf_companies['Company_Type'] == 'Pre-selected']

companies_sf_preselected.head()
# Out:
#     name category_code  number_of_employees total_money_raised country_code  \
# 1    hi5   games_video                100.0               $52M          USA
# 2  Zynga   games_video                115.0              $860M          USA
# 3   iWin   games_video                103.0                 $0          USA
#
#             city            address zip_code   latitude   longitude  \
# 1  San Francisco   55 Second Street    94105  37.788668 -122.400558
# 2  San Francisco    365 Vermont St.    94103  37.765158 -122.404234
# 3  San Francisco  45 Fremont Street    94105  37.781689 -122.391061
#
#    Company_Type
# 1  Pre-selected
# 2  Pre-selected
# 3  Pre-selected

# %%
df = pd.read_csv('../data/san_francisco_companies_cleaned_df.csv')

# %% [markdown]
# ## 1. FIRST FINALIST: HI5

# %%
hi5_venues_df = pd.read_csv('../data/hi5_venues_df.csv')

# %%
hi5_venues_df
# Out:
#                                                  name  \
# 0                                          Bar Fluxus
# 1                                 Sool Bar and Lounge
# 2                                       Uno Dos Tacos
# 3                                 Tequila Mockingbird
# 4                                      Sammy's on 2nd
# 5                                 Luke's Lobster SoMa
# 6                                    House of Shields
# 7                        Special Olympics Northern CA
# 8                                   111 Minna Gallery
# 9                                              Harlot
# 10                                                Meg
# 11                                      Local Edition
# 12                                          Starbucks
# 13                                          Starbucks
# 14                                          Starbucks
# 15                                    Starbucks Truck
# 16                                          Starbucks
# 17                                     Bluestone Lane
# 18                              Peet's Coffee and Tea
# 19                                               Mixt
# 20                                            Bun Mee
# 21            Bluestone Lane Union Square Coffee Shop
# 22                San Ramon Valley Unified School.dst
# 23                        Technapex Elementary School
# 24  Golden Gate Restaurant Association Scholarship...
# 25  Autodesk Authorized Training Centers Sfsu Down...
# 26                                            Year On
# 27                                   Basketball Court
# 28                   Google Cloud Courtside Lounge 25
# 29                               Chase Center Stadium
# 30                                        United Club
# 31                       USF - War Memorial Gymnasium
# 32                        Law Offices of Peter Roldan
# 33  Doggiedocs.com - Health, Nutrition, Training T...
# 34                      Peter N Hadiaris Attny At Law
# 35                               Peter Myers Law Firm
# 36                                    Sturges Peter W
#
#                       address           city            category  distance  \
# 0                18 Harlan Pl  San Francisco             karaoke       427
# 1               323 Grant Ave  San Francisco             karaoke       470
# 2               595 Market St  San Francisco                bars        42
# 3                   86 2nd St  San Francisco                bars        63
# 4                   84 2nd St  San Francisco                bars        64
# 5                   92 2nd St  San Francisco                bars        81
# 6        39 New Montgomery St  San Francisco                bars        82
# 7            109 Stevenson St  San Francisco               clubs        43
# 8                111 Minna St  San Francisco               clubs       172
# 9                 46 Minna St  San Francisco               clubs       186
# 10               1 Sansome St  San Francisco               clubs       258
# 11              691 Market St  San Francisco               clubs       266
# 12       74 New Montgomery St  San Francisco           starbucks        99
# 13           44 Montgomery St  San Francisco           starbucks       165
# 14                 100 1st St  San Francisco           starbucks       274
# 15              50 Fremont St  San Francisco           starbucks       374
# 16              264 Kearny St  San Francisco           starbucks       387
# 17                  55 2nd St  San Francisco   vegan restaurants        23
# 18              595 Market St  San Francisco   vegan restaurants        96
# 19             560 Mission St  San Francisco   vegan restaurants       125
# 20              650 Market St  San Francisco   vegan restaurants       187
# 21              685 Market St  San Francisco   vegan restaurants       227
# 22              582 Market St  San Francisco   elementary school       129
# 23             115 Sansome St  San Francisco   elementary school       313
# 24              720 Market St  San Francisco   elementary school       321
# 25              425 Market St  San Francisco   elementary school       347
# 26               44 Tehama St  San Francisco   elementary school       361
# 27          100 McAllister St  San Francisco  basketball stadium      1452
# 28                        NaN  San Francisco  basketball stadium      2535
# 29             1 Warriors Way  San Francisco  basketball stadium      2582
# 30  500 Terry A Francois Blvd  San Francisco  basketball stadium      2594
# 31       2100 Golden Gate Ave  San Francisco  basketball stadium      4487
# 32                  28 2nd St  San Francisco        pet-grooming        50
# 33                  28 2nd St  San Francisco        pet-grooming        50
# 34       55 New Montgomery St  San Francisco        pet-grooming        79
# 35              625 Market St  San Francisco        pet-grooming        91
# 36            71 Stevenson St  San Francisco        pet-grooming       100
#
#           lat         lon
# 0   37.790297 -122.405140
# 1   37.789993 -122.405695
# 2   37.789274 -122.400993
# 3   37.788120 -122.400280
# 4   37.788120 -122.400280
# 5   37.788038 -122.400060
# 6   37.788276 -122.401221
# 7   37.788428 -122.400943
# 8   37.787274 -122.399370
# 9   37.788570 -122.398227
# 10  37.790916 -122.401305
# 11  37.787566 -122.403258
# 12  37.787664 -122.401113
# 13  37.789534 -122.401869
# 14  37.789340 -122.397555
# 15  37.790766 -122.397281
# 16  37.790693 -122.403801
# 17  37.788770 -122.400318
# 18  37.789274 -122.400993
# 19  37.788743 -122.399384
# 20  37.788455 -122.402737
# 21  37.787598 -122.402830
# 22  37.789453 -122.401649
# 23  37.791458 -122.401050
# 24  37.787641 -122.403979
# 25  37.791156 -122.398164
# 26  37.787611 -122.396665
# 27  37.781084 -122.414131
# 28  37.768163 -122.387778
# 29  37.767924 -122.387478
# 30  37.767832 -122.387401
# 31  37.778096 -122.445491
# 32  37.788808 -122.401109
# 33  37.788808 -122.401109
# 34  37.788119 -122.401140
# 35  37.788672 -122.401603
# 36  37.789334 -122.399778

# %%
# Latitude and Longitude for Hi5
hi5_latitude = 37.788668
hi5_longitude = -122.400558

# Create a map centered around Hi5
map_hi5 = folium.Map(location=[hi5_latitude, hi5_longitude], zoom_start=40)

# Add a marker for Hi5
folium.Marker(
    [hi5_latitude, hi5_longitude],
    popup='Hi5',
    icon=folium.Icon(color='red', icon='info-sign'),
    z_index_offset=1000
).add_to(map_hi5)

# %%
other_companies = df[df['Company_Type'] != 'Pre-selected']

# Add markers for other companies
for idx, row in other_companies.iterrows():
    folium.Marker(
        [row['latitude'], row['longitude']],
        popup=row['name'],
        icon=folium.Icon(color='blue', icon='briefcase')
    ).add_to(map_hi5)

# %%
category_colors = {
    'karaoke': 'purple',
    'bars': 'purple',
    'clubs': 'purple',
    'starbucks': 'green',
    'vegan restaurants': 'orange',
    'elementary school': 'black',
    'basketball stadium': 'darkred',
    'pet-grooming': 'pink'
}

# Define a FontAwesome icon for each category
category_to_icon = {
    'karaoke': 'glass',
    'bars': 'glass',
    'clubs': 'glass',
    'starbucks': 'coffee',  # FontAwesome coffee icon for Starbucks
    'vegan restaurants': 'cutlery',
    'elementary school': 'graduation-cap',  # FontAwesome graduation cap icon for schools
    'basketball stadium': 'fa-bullseye',
    'pet-grooming': 'fa-paw',
    'default': 'info-sign'  
}

# Add markers for the venues
for idx, row in hi5_venues_df.iterrows():
    # Get the appropriate icon for the category
    icon_name = category_to_icon.get(row['category'], 'default') 

    # Set prefix to 'fa' for FontAwesome icons
    icon_prefix = 'fa' if row['category'] in ['starbucks', 'elementary school', 'basketball stadium', 'pet-grooming'] else None

    icon = folium.Icon(color=category_colors.get(row['category'], 'gray'),
                       icon=icon_name,
                       prefix=icon_prefix)

    folium.Marker(
        [row['lat'], row['lon']],
        popup=f"{row['name']} ({row['category']})",
        icon=icon
    ).add_to(map_hi5)

# %%
# Create dictionary for Montgomery Station
montgomery_station_dict = {
    'name': 'Montgomery Station',
    'address': '598 Market St, San Francisco, CA 94104, United States',
    'city': 'San Francisco',
    'category': 'rail station',
    'distance': 140,
    'lat': 37.7893598,
    'lon': -122.4013317
}

# Append the dictionary to the DataFrame
# First, convert the dictionary to a DataFrame
montgomery_station_df = pd.DataFrame([montgomery_station_dict])

# Then, concatenate it with the existing venues DataFrame
hi5_venues_df = pd.concat([hi5_venues_df, montgomery_station_df], ignore_index=True)

# %%
# Add a marker for Montgomery Station
folium.Marker(
    [montgomery_station_dict['lat'], montgomery_station_dict['lon']],
    popup=f"{montgomery_station_dict['name']} ({montgomery_station_dict['category']})",
    icon=folium.Icon(color='darkblue', icon='info-sign'),  # 'subway' is just an example; choose an appropriate icon
    z_index_offset=1000
).add_to(map_hi5)

# %%
map_hi5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1434a1e786c0705635033d6771cab4b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1434a1e786c0705635033d6771cab4b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1434a1e786c0705635033d6771cab4b8 = L.map(
#                 &quot;map_1434a1e786c0705635033d6771cab4b8&quot;,
#                 {
#                     center: [37.788668, -122.400558],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 40,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9b9220439fa6644bff881f06ad8d43b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1434a1e786c0705635033d6771cab4b8);
#
#
#             var marker_b3c91f8d62461894bd49bc5edd625808 = L.marker(
#                 [37.788668, -122.400558],
#                 {&quot;zIndexOffset&quot;: 1000}
#             ).addTo(map_1434a1e786c0705635033d6771cab4b8);
#
#
#             var icon_56ad9867518e4abf312e402b9d02832b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b3c91f8d62461894bd49bc5edd625808.setIcon(icon_56ad9867518e4abf312e402b9d02832b);
#
#
#         var popup_de70ca14924300b0ab5e0948ded40143 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3386581839529970dadfe179139dce37 = $(`&lt;div id=&quot;html_3386581839529970dadfe179139dce37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hi5&lt;/div&gt;`)[0];
#                 popup_de70ca14924300b0ab5e0948ded40143.setContent(html_3386581839529970dadfe179139dce37);
#
#
#
#         marker_b3c91f8d62461894bd49bc5edd625808.bindPopup(popup_de70ca14924300b0ab5e0948ded40143)
#         ;
#
#
#
#
#             var marker_447933805875e7712eb3061d90d0c2e3 = L.marker(
#                 [37.764726, -122.394523],
#                 {}
#             ).addTo(map_1434a1e786c0705635033d6771cab4b8);
#
#
#             var icon_889fef9972f74758a6c586e75d34b6b0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_447933805875e7712eb3061d90d0c2e3.setIcon(icon_889fef9972f74758a6c586e75d34b6b0);
#
#
#         var popup_ab705b7a7dd4bd02c5328ebe6bfc3140 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aadacaa87cf8be6b06ecca4b9864e718 = $(`&lt;div id=&quot;html_aadacaa87cf8be6b06ecca4b9864e718&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Digg&lt;/div&gt;`)[0];
#                 popup_ab705b7a7dd4bd02c5328ebe6bfc3140.setContent(html_aadacaa87cf8be6b06ecca4b9864e718);
#
#
#
#         marker_447933805875e7712eb3061d90d0c2e3.bindPopup(popup_ab705b7a7dd4bd02c5328ebe6bfc3140)
#         ;
#
#
#
#
#             var marker_8ee85e346875712e86d9257b76293384 = L.marker(
#                 [37.78976, -122.402524],
#                 {}
#             ).addTo(map_1434a1e786c0705635033d6771cab4b8);
#
#
#             var icon_41273676631bf8ef97ba20dad51aec79 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8ee85e346875712e86d9257b76293384.setIcon(icon_41273676631bf8ef97ba20dad51aec79);
#
#
#         var popup_005b6e9b9fe3b932d41831516a664521 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54f05fcb1dba2d6a41647dea14256701 = $(`&lt;div id=&quot;html_54f05fcb1dba2d6a41647dea14256701&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Prosper&lt;/div&gt;`)[0];
#                 popup_005b6e9b9fe3b932d41831516a664521.setContent(html_54f05fcb1dba2d6a41647dea14256701);
#
#
#
#         marker_8ee85e346875712e86d9257b76293384.bindPopup(popup_005b6e9b9fe3b932d41831516a664521)
#         ;
#
#
#
#
#             var marker_0e7c12984649cec582bd41cba5fceabf = L.marker(
#                 [37.757758, -122.388243],
#                 {}
#             ).addTo(map_1434a1e786c0705635033d6771cab4b8);
#
#
#             var icon_1a04dfd7c5c58b238917f4c4262f7213 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&qu
