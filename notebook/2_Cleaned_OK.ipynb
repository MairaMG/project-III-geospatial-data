# %%
from pymongo import MongoClient
import pandas as pd
import requests
import json

# %% [markdown]
# ## 1. Clean data about best markets to locate a gaming company

# %%
games_video_raw_df = pd.read_csv('../data/video_games_companies.csv')

# %%
games_video_raw_df
# Out:
#                        name category_code  number_of_employees  \
# 0                   Flektor   games_video                  NaN
# 1                      Lala   games_video                  NaN
# 2                     Joost   games_video                  0.0
# 3                  Babelgum   games_video                  NaN
# 4                   Sparter   games_video                  NaN
# ...                     ...           ...                  ...
# 1078  Symposium Productions   games_video                  NaN
# 1079              Rev Media   games_video                  NaN
# 1080             Fictionaut   games_video                  2.0
# 1081             Tiny Speck   games_video                 45.0
# 1082            My TV Shows   games_video                  2.0
#
#      total_money_raised country_code         city  \
# 0                    $0          USA  Culver City
# 1                $44.2M          USA    Palo Alto
# 2                  $45M          USA     New York
# 3                $13.2M          GBR       London
# 4                    $0          USA          NaN
# ...                 ...          ...          ...
# 1078                 $0          NaN          NaN
# 1079                 $0          USA       Dallas
# 1080                 $0          USA      Astoria
# 1081             $17.2M          CAN    Vancouver
# 1082                 $0          PRT       Lisbon
#
#                           address    zip_code   latitude   longitude
# 0     8536 National Blvd, Suite A       90232  34.025958 -118.379768
# 1                209 Hamilton Ave       94301  37.451151 -122.154369
# 2                100 5th Ave Fl 6  10011-6903  40.746497  -74.009447
# 3                             NaN         NaN  53.344104   -6.267494
# 4                             NaN         NaN  37.090240  -95.712891
# ...                           ...         ...        ...         ...
# 1078                          NaN         NaN        NaN         NaN
# 1079                          NaN         NaN        NaN         NaN
# 1080                32-14 42nd St       11103  40.759795  -73.916127
# 1081            163 Hastings St W  BC V6B 1H5  49.282455 -123.109217
# 1082       Rua RosÃ¡lia de Castro        1700  38.752367   -9.146221
#
# [1083 rows x 10 columns]

# %% [markdown]
# ### 1.1 I want to see null country values in case I can handdle them if I have any information that can point out where the company is located. Otherwise, I will drop this rows.

# %%
null_countries_count = games_video_raw_df['country_code'].isnull().sum()
null_countries_count
# Out:
# 244

# %%
# Drop rows where all specific columns are null at the same time
games_video_cleaned_df = games_video_raw_df.dropna(subset=['country_code', 'city', 'latitude', 'address','longitude', 'zip_code'], how='all')

# Display the shape of the DataFrame before and after the new cleaning to see how many rows were dropped
games_video_cleaned_shape = games_video_cleaned_df.shape

print(f'Shape before: {games_video_raw_df.shape}')
print(f'Shape after: {games_video_cleaned_df.shape}')
# Out:
# Shape before: (1083, 10)
# Shape after: (839, 10)

# %%
games_video_cleaned_df.to_csv('../data/video_games_companies_cleaned.csv', index=False)

# %% [markdown]
# ## 2. Clean data about possible offices in the USA

# %%
usa_companies_raw_df = pd.read_csv('../data/usa_companies.csv')

# %%
usa_companies_raw_df
# Out:
#                                 name category_code  number_of_employees  \
# 0                           Wetpaint           web                 47.0
# 1                          AdventNet    enterprise                600.0
# 2                               Zoho      software               1600.0
# 3                               Digg          news                 60.0
# 4                           Facebook        social               5299.0
# ...                              ...           ...                  ...
# 9261  Contemporary Computer Services      software                  NaN
# 9262                            QSGI      software                164.0
# 9263                      AfterLogic      software                  NaN
# 9264             EnteGreat Solutions      software                  NaN
# 9265                       EnteGreat    enterprise                  NaN
#
#      total_money_raised country_code           city  \
# 0                $39.8M          USA        Seattle
# 1                    $0          USA     Pleasanton
# 2                    $0          USA     Pleasanton
# 3                  $45M          USA  San Francisco
# 4                $2.43B          USA     Menlo Park
# ...                 ...          ...            ...
# 9261                 $0          USA        Bohemia
# 9262                 $0          USA     Palm Beach
# 9263                 $0          USA     Livingston
# 9264                 $0          USA     Birmingham
# 9265                 $0          USA     Birmingham
#
#                             address    zip_code   latitude   longitude
# 0                  710 - 2nd Avenue       98104  47.603122 -122.333253
# 1                  4900 Hopyard Rd.       94588  37.692934 -121.904945
# 2                   4900 Hopyard Rd       94588  37.692934 -121.904945
# 3                135 Mississippi St       94107  37.764726 -122.394523
# 4                  1601 Willow Road       94025  37.416050 -122.151801
# ...                             ...         ...        ...         ...
# 9261       200 Knickerbocker Avenue       11716  40.775055  -73.088140
# 9262             400 Royal Palm Way       33480  26.705331  -80.041395
# 9263                  P.O. Box 2096       07039  40.793024  -74.323554
# 9264                            NaN         NaN  33.518885  -86.816068
# 9265  1900 International Park Drive  35243-4204  33.407786  -86.761302
#
# [9266 rows x 10 columns]

# %% [markdown]
# ### 2.1 I want to drop all rows that have null values in the columns address, latitude and longitude at the same time

# %%
# Drop rows where all specific columns are null at the same time
usa_companies_cleaned_df = usa_companies_raw_df.dropna(subset=['latitude', 'address','longitude', 'zip_code'], how='all')

# Display the shape of the DataFrame before and after the new cleaning to see how many rows were dropped
usa_companies_cleaned_shape = usa_companies_cleaned_df.shape

print(f'Shape before: {usa_companies_raw_df.shape}')
print(f'Shape after: {usa_companies_cleaned_df.shape}')
# Out:
# Shape before: (9266, 10)
# Shape after: (9055, 10)

# %%
usa_companies_cleaned_df.to_csv('../data/usa_companies_cleaned.csv', index=False)

# %% [markdown]
# ## 3. Clean Design Companies and Companies that have raised more than 1M dollars

# %%
required_companies_raw_df = pd.read_csv('../data/required_companies.csv')

# %%
required_companies_raw_df
# Out:
#                          name  category_code total_money_raised country_code  \
# 0                        Digg           news               $45M          USA
# 1                       Joost    games_video               $45M          USA
# 2                     SpinVox      messaging              $106M          GBR
# 3                     AddThis    advertising               $73M          USA
# 4                      Mahalo            web               $21M          USA
# ...                       ...            ...                ...          ...
# 1651          Luminus Devices          other              $136M          USA
# 1652           Cameron Health        medical              $121M          USA
# 1653                 Cantimer            NaN                $2M          USA
# 1654  Celestial Semiconductor  semiconductor                $2M          USA
# 1655          InSound Medical        biotech               $11M          USA
#
#                  city                           address    zip_code  \
# 0       San Francisco                135 Mississippi St       94107
# 1            New York                  100 5th Ave Fl 6  10011-6903
# 2     Buckinghamshire        Wethered House, Pound Lane     SL7 2AF
# 3              Vienna             1595 Spring Hill Road       22182
# 4         Culver City                  3525 Eastham Dr.       90232
# ...               ...                               ...         ...
# 1651        Billerica        1100 Technology Park Drive       01821
# 1652     San Clemente                905 Calle Amanecer       92673
# 1653       Menlo Park                  3700 Haven Court       94025
# 1654         San Jose  2635 North 1st Street, Suite 150       95134
# 1655           Newark                39660 Eureka Drive       94560
#
#        latitude   longitude
# 0     37.764726 -122.394523
# 1     40.746497  -74.009447
# 2           NaN         NaN
# 3     38.926172  -77.245195
# 4     34.017606 -118.487267
# ...         ...         ...
# 1651  42.528635  -71.278022
# 1652  33.448010 -117.607717
# 1653  37.484616 -122.181753
# 1654  37.386417 -121.929170
# 1655  37.512038 -121.998513
#
# [1656 rows x 9 columns]

# %% [markdown]
# ### 3.1 I want companies only in San Francisco and New York

# %%
# Define the cities of interest for the new requirement
cities_of_interest_new = ['San Francisco', 'New York']

# Filter the dataframe for companies in San Francisco and New York
required_companies_cleaned_df = required_companies_raw_df[
    required_companies_raw_df['city'].isin(cities_of_interest_new)]

required_companies_cleaned_df.reset_index(drop=True, inplace=True)
required_companies_cleaned_df
# Out:
#                name     category_code total_money_raised country_code  \
# 0              Digg              news               $45M          USA
# 1             Joost       games_video               $45M          USA
# 2           Prosper           finance              $120M          USA
# 3    Pando Networks       games_video               $11M          USA
# 4         Revision3       games_video                $9M          USA
# ..              ...               ...                ...          ...
# 256         Teliris  public_relations               $11M          USA
# 257      WiNetworks            mobile               $19M          USA
# 258      TeachScape          software               $16M          USA
# 259         Roc2Loc         cleantech                $2M          USA
# 260    FinAnalytica          software                $7M          USA
#
#               city                           address    zip_code   latitude  \
# 0    San Francisco                135 Mississippi St       94107  37.764726
# 1         New York                  100 5th Ave Fl 6  10011-6903  40.746497
# 2    San Francisco                    101 2nd Street       94105  37.789760
# 3         New York                      520 Broadway       10012  40.722655
# 4    San Francisco                       2415 3rd St       94107  37.757758
# ..             ...                               ...         ...        ...
# 256       New York    100 William Street, Suite 1825       10038  42.902965
# 257       New York  555 West 57th Street, Suite 1326       10019  40.770437
# 258  San Francisco                  71 Stevenson St.       94105  37.786905
# 259  San Francisco         66 Mint Street, 3rd Floor       94103  37.782475
# 260       New York       100 Park Avenue, 16th Floor       10017  40.751293
#
#       longitude
# 0   -122.394523
# 1    -74.009447
# 2   -122.402524
# 3    -73.998730
# 4   -122.388243
# ..          ...
# 256  -78.883572
# 257  -73.990426
# 258 -122.404392
# 259 -122.407764
# 260  -73.978887
#
# [261 rows x 9 columns]

# %%
required_companies_cleaned_df.to_csv('../data/required_companies_cleaned.csv', index=False)

# %% [markdown]
# ## 4. Merging companies of interest

# %%
# Load the CSV files into DataFrames
pre_selected_df = pd.read_csv('../data/pre_selected_companies.csv')
required_companies_selected_df = pd.read_csv('../data/required_companies_cleaned.csv')

# Add an identifier column to the pre-selected DataFrame
pre_selected_df['Company_Type'] = 'Pre-selected'

# Assuming there's a column 'total_money_raised' to check if a company raised more than $1M
# And a column 'category_code' where 'design' might be a category for design companies
# Modify the lambda function to interpret strings with 'M'
required_companies_selected_df['Company_Type'] = required_companies_selected_df.apply(
    lambda x: 'Design' if x['category_code'] == 'design' 
    else ('Raised > $1M' if 'M' in str(x['total_money_raised']) else 'Other'),
    axis=1
)

# Concatenate the DataFrames
all_companies_df = pd.concat([pre_selected_df, required_companies_selected_df], ignore_index=True)

# If you need to remove duplicates
#all_companies_df.drop_duplicates(subset=['Company_Identifier_Column'], inplace=True)

# Inspect the combined DataFrame
all_companies_df
# Out:
#              name     category_code  number_of_employees total_money_raised  \
# 0      Livestream       games_video                120.0             $14.7M
# 1             hi5       games_video                100.0               $52M
# 2           Zynga       games_video                115.0              $860M
# 3            iWin       games_video                103.0                 $0
# 4           Exent       games_video                100.0                $3M
# ..            ...               ...                  ...                ...
# 261       Teliris  public_relations                  NaN               $11M
# 262    WiNetworks            mobile                  NaN               $19M
# 263    TeachScape          software                  NaN               $16M
# 264       Roc2Loc         cleantech                  NaN                $2M
# 265  FinAnalytica          software                  NaN                $7M
#
#     country_code           city                           address zip_code  \
# 0            USA       New York             111 8th Avenue, #1509    10011
# 1            USA  San Francisco                  55 Second Street    94105
# 2            USA  San Francisco                   365 Vermont St.    94103
# 3            USA  San Francisco                 45 Fremont Street    94105
# 4            USA       New York                   632 W. 28th St.    10001
# ..           ...            ...                               ...      ...
# 261          USA       New York    100 William Street, Suite 1825    10038
# 262          USA       New York  555 West 57th Street, Suite 1326    10019
# 263          USA  San Francisco                  71 Stevenson St.    94105
# 264          USA  San Francisco         66 Mint Street, 3rd Floor    94103
# 265          USA       New York       100 Park Avenue, 16th Floor    10017
#
#       latitude   longitude  Company_Type
# 0    40.726155  -73.995625  Pre-selected
# 1    37.788668 -122.400558  Pre-selected
# 2    37.765158 -122.404234  Pre-selected
# 3    37.781689 -122.391061  Pre-selected
# 4    40.752380  -74.005568  Pre-selected
# ..         ...         ...           ...
# 261  42.902965  -78.883572  Raised > $1M
# 262  40.770437  -73.990426  Raised > $1M
# 263  37.786905 -122.404392  Raised > $1M
# 264  37.782475 -122.407764  Raised > $1M
# 265  40.751293  -73.978887  Raised > $1M
#
# [266 rows x 11 columns]

# %%
# Drop duplicates
all_companies_cleaned_df = all_companies_df.drop_duplicates()
all_companies_cleaned_df
# Out:
#              name     category_code  number_of_employees total_money_raised  \
# 0      Livestream       games_video                120.0             $14.7M
# 1             hi5       games_video                100.0               $52M
# 2           Zynga       games_video                115.0              $860M
# 3            iWin       games_video                103.0                 $0
# 4           Exent       games_video                100.0                $3M
# ..            ...               ...                  ...                ...
# 261       Teliris  public_relations                  NaN               $11M
# 262    WiNetworks            mobile                  NaN               $19M
# 263    TeachScape          software                  NaN               $16M
# 264       Roc2Loc         cleantech                  NaN                $2M
# 265  FinAnalytica          software                  NaN                $7M
#
#     country_code           city                           address zip_code  \
# 0            USA       New York             111 8th Avenue, #1509    10011
# 1            USA  San Francisco                  55 Second Street    94105
# 2            USA  San Francisco                   365 Vermont St.    94103
# 3            USA  San Francisco                 45 Fremont Street    94105
# 4            USA       New York                   632 W. 28th St.    10001
# ..           ...            ...                               ...      ...
# 261          USA       New York    100 William Street, Suite 1825    10038
# 262          USA       New York  555 West 57th Street, Suite 1326    10019
# 263          USA  San Francisco                  71 Stevenson St.    94105
# 264          USA  San Francisco         66 Mint Street, 3rd Floor    94103
# 265          USA       New York       100 Park Avenue, 16th Floor    10017
#
#       latitude   longitude  Company_Type
# 0    40.726155  -73.995625  Pre-selected
# 1    37.788668 -122.400558  Pre-selected
# 2    37.765158 -122.404234  Pre-selected
# 3    37.781689 -122.391061  Pre-selected
# 4    40.752380  -74.005568  Pre-selected
# ..         ...         ...           ...
# 261  42.902965  -78.883572  Raised > $1M
# 262  40.770437  -73.990426  Raised > $1M
# 263  37.786905 -122.404392  Raised > $1M
# 264  37.782475 -122.407764  Raised > $1M
# 265  40.751293  -73.978887  Raised > $1M
#
# [252 rows x 11 columns]

# %%
all_companies_cleaned_df.to_csv('../data/all_companies_cleaned_df.csv', index=False)

# %% [markdown]
# ## 5. Cleaning Latitude and Longitude from the Final Dataframe

# %%
# Create a copy of the DataFrame to avoid SettingWithCopyWarning
all_companies_cleaned_df = all_companies_cleaned_df.copy()

# Define the function to convert and handle NA values
def convert_to_float(value):
    if pd.isna(value):
        return pd.NA
    elif value == "Throttled! See geocode.xyz/pricing":
        return pd.NA
    else:
        try:
            return float(value)
        except ValueError:
            return pd.NA

# Apply the function to the 'latitude' and 'longitude' columns
all_companies_cleaned_df['latitude'] = all_companies_cleaned_df['latitude'].apply(convert_to_float)
all_companies_cleaned_df['longitude'] = all_companies_cleaned_df['longitude'].apply(convert_to_float)

# %%
# Drop rows with "Unknown" in 'address' column
all_companies_cleaned_df = all_companies_cleaned_df[all_companies_cleaned_df['address'] != "Unknown"]

# Drop rows with NaN in 'latitude' or 'longitude' columns
all_companies_cleaned = all_companies_cleaned_df.dropna(subset=['latitude', 'longitude'])

# Check the first few rows to verify the changes
all_companies_cleaned_df.to_csv('../data/all_companies_cleaned_df.csv', index=False)

# %%
from getpass import getpass
import time
import os
from dotenv import load_dotenv
import numpy as np

# %%
load_dotenv()  # Take environment variables from .env.
# Out:
# True

# %%
token = os.getenv("token")

# %%
MAX_ATTEMPTS = 3

def gets_coordinates_from_string (address, attemps):
    if attemps > MAX_ATTEMPTS:
        return None
    
    url_geocode = f"https://geocode.xyz/{address}?json=1"
    res = requests.get(url_geocode)
    
    try:
        response = res.json()
        
        # The API can fail in two ways, it either didn't find the address or the call was throttled
        if 'latt' in response and 'Throttled' not in response['latt']:
            return response
    except ex:
        print(f"Couldn't get geo data for {address}, attempts: {attempts}, error: {str(ex)}")
        
    # If we get here we haven't found geo data yet
    time.sleep(10)
    return gets_coordinates_from_string(address,attemps+1)

# %%
row = {'address': '201 Third Street, 2nd Floor', 'city': 'San Francisco'}
full_address = f"{row['address']}, {row['city']}"
test1 = gets_coordinates_from_string(full_address, 0)
test1
# Out:
# {'standard': {'stnumber': '4732',
#   'addresst': 'Third Street',
#   'statename': 'California',
#   'postal': {},
#   'region': 'CA',
#   'prov': 'US',
#   'city': 'San Francisco',
#   'countryname': 'United States of America',
#   'confidence': '0.9'},
#  'longt': '-122.39078',
#  'alt': {},
#  'elevation': {},
#  'latt': '37.73518'}

# %%
# First, filter out rows where latitude and longitude are missing
#companies_to_geocode = all_companies_cleaned_df[all_companies_cleaned_df['latitude'].isnull() | all_companies_cleaned_df['longitude'].isnull()]

# Then loop through these companies and geocode them
for index, row in all_companies_cleaned_df.iterrows():    
    row_lat = all_companies_cleaned_df.at[index, 'latitude']
    row_lng = all_companies_cleaned_df.at[index, 'longitude']
    address = all_companies_cleaned_df.at[index, 'address']
    
    lat_or_lng_empty = pd.isna(row_lat) and pd.isna(row_lng)
    has_address = type(address) == str
    
    # We only add information to rows that don't have lat and lng, that also have an address for search
    if lat_or_lng_empty and has_address:
        city = all_companies_cleaned_df.at[index, 'city']
        
        # We concat address and city to increase reliability
        full_address = f"{address}, {city}"
        print(f"Getting the geo data for {full_address}")
        
        response = gets_coordinates_from_string(full_address, 0)
        
        if response is None:
            print(f"Couldn't get geo data for address {full_address}")
            continue
        
        api_lat = float(response['latt'])
        api_lng = float(response['longt'])

        # Update the DataFrame with the new latitude and longitude
        all_companies_cleaned_df.at[index, 'latitude'] = api_lat
        all_companies_cleaned_df.at[index, 'longitude'] = api_lng

        # API rate limit
        time.sleep(5)

# Save the updated DataFrame
all_companies_cleaned_df.to_csv('../data/all_companies_cleaned_df.csv', index=False)
# Out:
# 40.726155 -73.995625
# 37.788668 -122.400558
# 37.765158 -122.404234
# 37.781689 -122.391061
# 40.7523796 -74.005568
# 37.764726 -122.394523
# 40.7464969 -74.0094471
# 37.78976 -122.402524
# 40.722655 -73.99873
# 37.757758 -122.388243
# 37.786183 -122.402195
# 40.7516611 -73.9843328
# 37.789268 -122.395184
# 37.781427 -122.392144
# 37.782103 -122.401116
# 37.762681 -122.400909
# 37.779507 -122.39071
# 37.775196 -122.419204
# 37.793703 -122.398479
# 37.788668 -122.400558
# 37.787092 -122.399972
# 40.7311317 -73.9919311
# 51.500152 -0.126236
# 37.437328 -122.159928
# <NA> <NA>
# Getting the geo data for 201 Third Street, 2nd Floor, San Francisco
# 37.779507 -122.39071
# 37.7911148 -122.3954751
# 37.786942 -122.401245
# 40.751816 -73.971655
# 37.762125 -122.4147
# 37.789488 -122.397593
# 40.753385 -73.98962
# 37.766909 -122.406676
# 37.09024 -95.712891
# 37.785647 -122.405265
# 40.7445343 -73.9874008
# 40.7244 -73.99732
# 40.72948 -74.000195
# 37.768708 -122.402866
# 40.745216 -73.982807
# 37.765125 -122.4044034
# 37.783898 -122.395234
# 37.856331 -122.495222
# 40.781159 -73.978332
# 37.782809 -122.394354
# 40.743808 -73.983626
# 37.7753 -122.398058
# 40.621591 -73.960717
# 40.741266 -73.990753
# 37.791733 -122.398398
# 37.787126 -122.39783
# 40.907974 -73.84179
# 40.7550005 -73.9717364
# 37.794643 -122.401144
# 37.762162 -122.413912
# 40.74092 -73.99184
# 37.803847 -122.402468
# 38.984172 -77.095965
# 37.78274 -122.390945
# <NA> <NA>
# Getting the geo data for Church Street Station, New York
# 40.742459 -73.9918126
# 37.7766184 -122.3938931
# 37.09024 -95.712891
# 40.74727 -73.9800645
# 40.740231 -73.985433
# 37.7876952 -122.3991505
# 40.755978 -73.990396
# 37.559836 -122.271532
# 37.78624 -122.39897
# 37.771706 -122.402683
# 40.73333 -73.99305
# 37.09024 -95.712891
# 25.752358 -80.25468
# 37.392443 -122.072517
# 37.856743 -122.480153
# 40.75362 -73.986557
# 37.765158 -122.404234
# 37.78795 -122.40667
# 37.79713 -122.39468
# 37.75672 -122.40507
# 40.752325 -73.988477
# 37.7759675 -122.3931128
# 40.743662 -73.984268
# 40.723652 -73.985281
# 40.74632 -73.982607
# 40.717248 -74.002662
# 37.7955307 -122.4005983
# 37.787183 -122.397759
# 37.7885714 -122.4035985
# 37.79315 -122.39848
# 40.732748 -73.992607
# 37.776878 -122.400934
# 29.4748 -81.1274
# 37.76785 -122.392839
# <NA> <NA>
# Getting the geo data for 156a Reade St, New York
# 40.74177 -73.99561
# 37.773727 -122.401537
# 37.773688 -122.423468
# 40.7509033 -73.9779759
# 37.78115 -122.39481
# 40.761855 -73.983754
# 37.792083 -122.3946404
# 37.789551 -122.40036
# 37.775196 -122.419204
# 40.75406 -73.999003
# 37.7893215 -122.4013624
# 37.791242 -122.397133
# 37.3944561 -122.0785314
# 40.234451 -111.658656
# 37.777513 -122.397044
# 40.7455068 -73.982624
# 40.7310476 -74.0078134
# 37.7915 -122.40045
# 37.7886685 -122.4005576
# 37.782101 -122.389519
# 40.753403 -73.989189
# 37.7886717 -122.392725
# 40.739341 -73.988357
# 37.766909 -122.406676
# 37.787646 -122.402759
# 40.7309047 -74.006311
# 40.7368158 -73.9955426
# 40.74812 -73.98423
# 37.7850326 -122.4004738
# 37.782085 -122.409747
# 37.78302 -122.39469
# 40.65467 -74.00557
# 37.805289 -122.404448
# 40.755253 -73.992152
# <NA> <NA>
# Getting the geo data for 888 Brannan Street, San Francisco
# 40.7250495 -73.9970912
# 37.7976785 -122.4018163
# 37.798684 -122.40264
# 37.796903 -122.404904
# 40.74525 -73.99032
# 40.70566 -74.01315
# 37.796843 -122.400346
# 37.776246 -122.4179223
# 37.777092 -122.391011
# 37.580093 -122.347745
# 37.7870923 -122.3999719
# 40.70512 -74.0114
# 37.78691 -122.404403
# 37.37027 -121.924053
# 37.75672 -122.40507
# 40.733928 -73.991334
# 37.804619 -122.371203
# 40.7568493 -73.9793465
# 50.095312 9.049981
# 40.738143 -74.008159
# 37.79811 -122.4023
# 37.77772 -122.395785
# 37.79255 -122.40002
# 40.7451545 -73.9869549
# 37.79172 -122.39826
# <NA> <NA>
# Getting the geo data for 333 Bush Street, San Francisco
# 37.7898499 -122.4006831
# 37.7759421 -122.3931139
# 37.3792486 -122.1151274
# 37.79458 -122.4019
# 37.7710402 -122.4026325
# 37.7877967 -122.3989376
# 40.739867 -73.990024
# 40.7538639 -73.9785086
# 37.7965781 -122.4022856
# 40.7103 -73.96523
# 37.665469 -122.38222
# 40.769375 -73.982635
# 40.737216 -73.990947
# 34.0497638 -118.2474287
# <NA> <NA>
# Getting the geo data for 134 W.37th St., 2nd Fl., New York
# <NA> <NA>
# Getting the geo data for 456 Montgomery, San Francisco
# 37.77121 -122.41949
# 37.7887135 -122.3927145
# 37.7900992 -122.4021988
# 37.789801 -122.395327
# 37.7800788 -122.3943096
# <NA> <NA>
# Getting the geo data for 242 W. 27th ST, New York
# Couldn't get geo data for address 242 W. 27th ST, New York
# 37.796396 -122.404869
# 37.78667 -122.40505
# 37.785271 -122.397582
# 40.73992 -73.99098
# 37.7800539 -122.3912492
# 40.75688 -73.98583
# 40.7429533 -73.9844611
# 40.752844 -73.978324
# 37.795141 -122.401194
# 40.762674 -73.9821315
# 40.7038257 -74.0083282
# 40.72774 -74.00744
# 40.752672 -73.97593
# 47.6023367 -122.2850112
# 40.7454971 -73.9826042
# 40.7244 -73.99732
# 37.7775896 -122.3956019
# 37.778551 -122.391686
# 37.75672 -122.40507
# 37.79662 -122.4019
# <NA> <NA>
# Getting the geo data for 1355 Market St, San Francisco
# 40.75268 -73.97537
# 40.72541 -74.00469
# 37.78978 -122.40426
# 37.789471 -122.404113
# 37.7757 -122.41808
# 37.788864 -122.4008487
# 40.750823 -73.985833
# 37.7870283 -122.4000192
# 37.7676285 -122.393799
# 40.707954 -74.011114
# 40.75212 -74.00523
# 37.7871306 -122.4041075
# 40.75205 -74.00505
# 40.76253 -73.99614
# 37.7871306 -122.4041075
# 37.75672 -122.40507
# 37.805289 -122.404448
# 40.755531 -73.980861
# 37.4484914 -122.1802812
# 37.781689 -122.391061
# 40.7523796 -74.005568
# 40.72641 -73.984716
# 40.756054 -73.986951
# 42.9029654 -78.883572
# 40.770437 -73.990426
# 37.7869047 -122.4043924
# 37.782475 -122.407764
# 40.751293 -73.978887

# %%
len(all_companies_cleaned_df)
# Out:
# 252

# %% [markdown]
# ## 6. Cleaning San Francisco Companies as there are some wrong latitudes and longitudes

# %%
sf_companies_df = pd.read_csv('../data/san_francisco_companies.csv')

# %%
# Identify incorrect coordinates by converting them to strings and checking the prefix
incorrect_latitudes = sf_companies_df['latitude'].astype(str).str.startswith('37') == False
incorrect_longitudes = sf_companies_df['longitude'].astype(str).str.startswith('-122') == False

# Get the indices of the rows with incorrect coordinates
incorrect_coords_indices = sf_companies_df[incorrect_latitudes | incorrect_longitudes].index

# Display the rows with incorrect coordinates
incorrect_coords_df = sf_companies_df.loc[incorrect_coords_indices]
incorrect_coords_df[['name', 'address','latitude', 'longitude']]
# Out:
# Empty DataFrame
# Columns: [name, address, latitude, longitude]
# Index: []

# %%
sf_companies_df.at[103, 'latitude'] = 37.7820311
sf_companies_df.at[103, 'longitude'] = -122.3957106

# %%
sf_companies_df.at[89, 'latitude'] = 37.8017812
sf_companies_df.at[89, 'longitude'] = -122.4040438

# %%
sf_companies_df.at[65, 'latitude'] = 37.771696
sf_companies_df.at[65, 'longitude'] = -122.4025698

# %%
sf_companies_df.at[43, 'latitude'] = 37.7902397
sf_companies_df.at[43, 'longitude'] = -122.4027193

# %%
sf_companies_df.at[16, 'latitude'] = 37.7919443
sf_companies_df.at[16, 'longitude'] = -122.4026277

# %%
sf_companies_df
# Out:
#                      name category_code  number_of_employees  \
# 0                     hi5   games_video                100.0
# 1                   Zynga   games_video                115.0
# 2                    iWin   games_video                103.0
# 3                    Digg          news                  NaN
# 4                 Prosper       finance                  NaN
# ..                    ...           ...                  ...
# 129      Recurrent Energy     cleantech                  NaN
# 130  Siluria Technologies      nanotech                  NaN
# 131           ZoomSystems      hardware                  NaN
# 132            TeachScape      software                  NaN
# 133               Roc2Loc     cleantech                  NaN
#
#     total_money_raised country_code           city                    address  \
# 0                 $52M          USA  San Francisco           55 Second Street
# 1                $860M          USA  San Francisco            365 Vermont St.
# 2                   $0          USA  San Francisco          45 Fremont Street
# 3                 $45M          USA  San Francisco         135 Mississippi St
# 4                $120M          USA  San Francisco             101 2nd Street
# ..                 ...          ...            ...                        ...
# 129               $85M          USA  San Francisco         300 California St.
# 130              $103M          USA  San Francisco        409 Illinois Street
# 131               $87M          USA  San Francisco    22 4th Street, Floor 16
# 132               $16M          USA  San Francisco           71 Stevenson St.
# 133                $2M          USA  San Francisco  66 Mint Street, 3rd Floor
#
#     zip_code   latitude   longitude  Company_Type
# 0      94105  37.788668 -122.400558  Pre-selected
# 1      94103  37.765158 -122.404234  Pre-selected
# 2      94105  37.781689 -122.391061  Pre-selected
# 3      94107  37.764726 -122.394523  Raised > $1M
# 4      94105  37.789760 -122.402524  Raised > $1M
# ..       ...        ...         ...           ...
# 129    94104  37.805289 -122.404448  Raised > $1M
# 130    94158  37.448491 -122.180281  Raised > $1M
# 131    94103  37.781689 -122.391061  Raised > $1M
# 132    94105  37.786905 -122.404392  Raised > $1M
# 133    94103  37.782475 -122.407764  Raised > $1M
#
# [134 rows x 11 columns]

# %%
# Check for duplicates based on the 'name' column only and keep the first occurrence
sf_cleaned_df = sf_companies_df.drop_duplicates(subset=['name'], keep='first')

# %%
sf_cleaned_df
# Out:
#                      name category_code  number_of_employees  \
# 0                     hi5   games_video                100.0
# 1                   Zynga   games_video                115.0
# 2                    iWin   games_video                103.0
# 3                    Digg          news                  NaN
# 4                 Prosper       finance                  NaN
# ..                    ...           ...                  ...
# 129      Recurrent Energy     cleantech                  NaN
# 130  Siluria Technologies      nanotech                  NaN
# 131           ZoomSystems      hardware                  NaN
# 132            TeachScape      software                  NaN
# 133               Roc2Loc     cleantech                  NaN
#
#     total_money_raised country_code           city                    address  \
# 0                 $52M          USA  San Francisco           55 Second Street
# 1                $860M          USA  San Francisco            365 Vermont St.
# 2                   $0          USA  San Francisco          45 Fremont Street
# 3                 $45M          USA  San Francisco         135 Mississippi St
# 4                $120M          USA  San Francisco             101 2nd Street
# ..                 ...          ...            ...                        ...
# 129               $85M          USA  San Francisco         300 California St.
# 130              $103M          USA  San Francisco        409 Illinois Street
# 131               $87M          USA  San Francisco    22 4th Street, Floor 16
# 132               $16M          USA  San Francisco           71 Stevenson St.
# 133                $2M          USA  San Francisco  66 Mint Street, 3rd Floor
#
#     zip_code   latitude   longitude  Company_Type
# 0      94105  37.788668 -122.400558  Pre-selected
# 1      94103  37.765158 -122.404234  Pre-selected
# 2      94105  37.781689 -122.391061  Pre-selected
# 3      94107  37.764726 -122.394523  Raised > $1M
# 4      94105  37.789760 -122.402524  Raised > $1M
# ..       ...        ...         ...           ...
# 129    94104  37.805289 -122.404448  Raised > $1M
# 130    94158  37.448491 -122.180281  Raised > $1M
# 131    94103  37.781689 -122.391061  Raised > $1M
# 132    94105  37.786905 -122.404392  Raised > $1M
# 133    94103  37.782475 -122.407764  Raised > $1M
#
# [132 rows x 11 columns]

# %%
sf_cleaned_df.to_csv('../data/san_francisco_companies_cleaned_df.csv', index=False)
